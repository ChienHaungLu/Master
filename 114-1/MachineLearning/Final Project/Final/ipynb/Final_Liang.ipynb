# %% [markdown]
# <a href="https://colab.research.google.com/github/RLungWu/NCKU-ML-25Fall/blob/main/Final%20Project/Final_Liang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unzip Data

# %%
# !unzip "/content/drive/MyDrive/NCKU/Machine Learning/Final Project/FinalProject/negative-20251022T114258Z-1-003.zip"
# !unzip "/content/drive/MyDrive/NCKU/Machine Learning/Final Project/FinalProject/positive-20251022T114300Z-1-003.zip"
# !unzip "/content/drive/MyDrive/NCKU/Machine Learning/Final Project/positive003.zip"
# Out:
# Archive:  /content/drive/MyDrive/NCKU/Machine Learning/Final Project/FinalProject/negative-20251022T114258Z-1-003.zip
# replace negative/93.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: negative/93.png
# replace negative/88.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace negative/88.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace negative/88.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: negative/88.png
#   inflating: negative/91.png
#   inflating: negative/89.png
#   inflating: negative/87.png
#   inflating: negative/84.png
#   inflating: negative/90.png
#   inflating: negative/83.png
#   inflating: negative/86.png
#   inflating: negative/80.png
#   inflating: negative/85.png
#   inflating: negative/81.png
#   inflating: negative/77.png
#   inflating: negative/78.png
#   inflating: negative/82.png
#   inflating: negative/76.png
#   inflating: negative/79.png
# ...

# %% [markdown]
# # Model
#
# Pathology Foundation Model: https://github.com/mahmoodlab/UNI
# Model Architecture: **UNet Transformers**
# This is a model based on UNET transformers using UNI pathology pretrained foundation model

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# # Train

# %% [markdown]
# # Error Analysis
